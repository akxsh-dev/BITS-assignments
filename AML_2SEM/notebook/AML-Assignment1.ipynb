# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Load dataset
file_path = r'D:\MTech\sem 2\AML\assignment\Crop_recommendation.csv'
df = pd.read_csv(file_path)

# %%
#Sanity Check
print(df.head(2))
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice

# %%
# Class Imbalance
sns.countplot(x='label', data=df)
plt.show()

# %%
df.hist(bins=15, figsize=(15, 10), layout=(3, 3))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=df.drop('label', axis=1))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='temperature', y='humidity', hue='label', data=df)
plt.show()

# %%
# Exclude the 'label' column for correlation matrix calculation
correlation_matrix = df.drop('label', axis=1).corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()
